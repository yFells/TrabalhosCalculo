# %% [markdown]
# <a href="https://colab.research.google.com/github/yFells/TrabalhosCalculo/blob/main/Prova2CALC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nome: Felipe de Lima dos Santos

# %% [markdown]
# # Questão 1 (vale 6 pontos)
# Considerando as funções listadas a seguir faça: **(a)** o gráfico das três funções; **(b)** o passo a passo algébrico, em latex, para encontrar o ângulo de inclinação da reta tangente no ponto $x=5$ para cada das funções:
#
# 1. $
# f(x) = (x^2 - 4)(x^3 - 7x + 1)
# $
# 2. $
# f(x) = \sin(x^2)\cos(2x)
# $
# 3.$
# f(x) = x^2e^{-x}\ln(x)
# $
#
# Se você usar o sympy, terá que fazer com que ele imprima todos os passos necessários para resolver cada uma das operações, regras, ou tabelas que aplicar para resolver o problema.
#
# Em todas as questões você pode usar apenas os métodos, regras, técnicas e algoritmos que utilizamos na nossa disciplina, em sala, ou no material de apoio.

# %%
#PASSO A

import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

x = sp.Symbol('x')

x = np.linspace(-5, 25, 1000)

f1 = ((x**2)-4)*((x**3)-7*x+1)
f2 = np.sin(x**2)*np.cos(2*x)
f3 = (x**2)*np.exp(-x)*np.log(x)

plt.axis([-5, 5, -30, 20])
plt.plot(x, f1)
plt.show()

plt.axis([-5, 5, -2, 2])
plt.plot(x,f2)
plt.show()

plt.axis([0, 6, -1, 1])
plt.plot(x,f3)
plt.show()
# Out:
# <ipython-input-96-8f7010b7d704>:13: RuntimeWarning:
#
# invalid value encountered in log

# %% [markdown]
# 1.
# $
# f(x) = (x^2 - 4)(x^3 - 7x + 1)
# $
#
# 1.1 $
# \frac{d}{dx}\left(x^2-4\right) -> \frac{d}{dx}\left(x^2\right) - \frac{d}{dx}\left(4\right)
# $
#
# 1.2 $
# \frac{d}{dx}\left(x^2\right) = 2x - \frac{d}{dx}\left(4\right) = 0
# $
#
# 1.3 $
# 2x - 0 = 2x
# $
#
# 1.4.$
# \frac{d}{dx}\left(x^3-7x+1\right) -> \frac{d}{dx}\left(x^3\right) - \frac{d}{dx}\left(7x\right) - \frac{d}{dx}\left(1\right)
# $
#
# 1.5 $
# \frac{d}{dx}\left(x^3\right) = 3x^2- \frac{d}{dx}\left(7x\right) = 7 - \frac{d}{dx}\left(1\right) = 0
# $
#
# 1.6 $
# f(x) = (2x)*(3x^2+7)
# $
#
# 1.7 $
# f'(x) = ((x^2)-4)(3x^2 - 7) + ((x^3)-7x+1)*(2x)
# $
#
# 1.8 $
# f'(x) = 5x^4-33x^2+2x+28
# $
#
# 1.9 $
# f'(x) = ((25)-4)(75 - 7) + (91)*(10) - >
# f'(x) = (1.428) + (910) = 2.338
# $
#
# Para encontrar o ângulo de inclinação da reta tangente
#
# Ângulo de inclinação $
# arctan(2338) = 1.57036\dots
# $
#
#
# Ângulo de inclinação $
#  1.5655 $ radianos $ ≈ 89.8502 $ graus
#
# 2.
# $
# f(x) = \sin(x^2)\cos(2x)
# $
#
# 2.1 $
# \frac{d}{dx}\left(\sin(x^2)\right) -> \cos \left(x^2\right)\frac{d}{dx}\left(x^2\right) -> \cos \left(x^2\right) * 2x
# $
#
# 2.2 $
# \frac{d}{dx}\left(\cos(2x)\right) -> -\sin \left(2x\right) *\frac{d}{dx}\left(2x\right) -> -\sin \left(2x\right)*2
# $
#
# 2.3 $
# f(x) = (\cos \left(x^2\right) * 2x) * \cos(2x) + \sin(x^2) * (-\sin \left(2x\right)*2)
# $
#
# 2.4 $
# f(5) = (\cos \left(5^2\right) * 2*5) * \cos(2*5) + \sin(5^2) * (-\sin \left(2*5\right)*2)
# $
#
# 2.5 $
# f'(5) ≈ 0.5706
# $
#
# 2.7 Para encontrar o ângulo de inclinação da reta tangente
#
# Ângulo de inclinação $
# arctan(0.5706) = 0.51852\dots
# $
#
#
# Ângulo de inclinação $
#   0.51852 $ radianos $ ≈ 29.843 $ graus
#
# 3.
# $
# f(x) = x^2e^{-x}\ln(x)
# $
#
# 3.1 $
# \frac{d}{dx}\left(x^2e^{-x}\right) = (2x)e^{-x} + x^2(-e^{-x})
# $
#
# 3.2 $
# \frac{d}{dx}\left(\ln(x)\right) = \frac{1}{x}
# $
#
# 3.3 $
# f'(x) = ((2x)e^{-x} + x^2(-e^{-x})) * ln(x) + (x^2*e^{-x}) * (\frac{1}{x})
# $
#
# 3.4 $
# f'(x) = (2x - x^2) * e^{-x} * ln(x) + x * e^{-x}
# $
#
# 3.5 $
# f'(5) = (2(5) - 5^2) * e^{-5} * ln(5) + 5 * e^{-5}
# $
#
# 3.6 $
# f'(5) ≈ -0.12918249705
# $
#
# 3.7 Para encontrar o ângulo de inclinação da reta tangente
#
# Ângulo de inclinação $
# arctan(-0.12918249705) ≈ -7.405 $ graus

# %% [markdown]
# # Questão 2 (vale 2 pontos)
# Uma empresa espacial está tentando descobrir o ponto máximo da órbita de um satélite cuja função orbital é dada por:
# $$f(x)=x^4−5x^3+10x^2−10x+5$$
#
# Encontre o primeiro ponto de mínimo no intervalo $-10<=x<=10$.
#
# Como sempre, você pode usar qualquer ferramenta disponível na internet para lhe auxiliar a resolver este problema. Lembre-se, contudo, que o sympy é uma boa alternativa. Em todos os casos, (FOI DITO EM SALA QUE NÃO PRECISA DO PASSO A PASSO NA 2 ) ~você precisará indicar o passo a passo da aplicação de todas as regras, técnicas, matrizes, ou tabelas que use para resolver este problema.~
#
# Em todas as questões você pode usar apenas os métodos, regras, técnicas e algoritmos que utilizamos na nossa disciplina, em sala, ou no material de apoio. Lembrem-se estamos limitados as bibliotecas sympy, numpy e matplotlib.
#
# Para resolver esta questão você precisará de, no minimo, 4 casas decimais de precisão depois da vírgula.

# %%
def f(x):
    return x**4 - 5*x**3 + 10*x**2 - 10*x + 5

# INTERVALO
x_inicial = -10
x_final = 10
delta_x = 0.0001 #DECIMAIS

min_x = None
min_y = float('inf')

# Realizar a busca por intervalo
x = x_inicial
while x <= x_final:
    y = f(x)
    if y < min_y:
        min_x = round(x, 8)
        min_y = round(y, 8)
    x += delta_x

print(f'O primeiro ponto de mínimo ocorre em x = {min_x}')
# Out:
# O primeiro ponto de mínimo ocorre em x = 1.6058

# %% [markdown]
# # Questão 3 (vale 2 pontos)
# Considerando a função $f(x,y) = \sin(xy) + \cos(x+y)$, no intervalo $0\leq x\leq 5 \space\space e \space\space 0\leq y\leq 5$ trace, usando o plotly o gráfico desta função e marque os pontos de máximo e mínimo neste intevalo.
#
# Lembre-se o sympy é sempre uma opção e você pode usar qualquer técnica, algoritmo, regra, ou tabela, que tenha sido usada na matéria. E que precisa de apenas uma casa decimal de precisão. Uma dica importante para a solução deste problema é a função **np.unravel_index**

# %%
import plotly.graph_objects as go
import numpy as np

def f(x, y):
    return np.sin(x * y) + np.cos(x + y)

x_values = np.linspace(0, 5, 100)
y_values = np.linspace(0, 5, 100)

x_grid, y_grid = np.meshgrid(x_values, y_values)
z_values = f(x_grid, y_grid)

max_point = np.unravel_index(np.argmax(z_values), z_values.shape)
min_point = np.unravel_index(np.argmin(z_values), z_values.shape)

fig = go.Figure()

fig.add_trace(
    go.Surface(
        x=x_grid,
        y=y_grid,
        z=z_values
    )
)

fig.add_trace(
    go.Scatter3d(
        x=[x_values[max_point[1]]],
        y=[y_values[max_point[0]]],
        z=[z_values[max_point]],
        mode='markers',
        marker=dict(color='green', size=5),
        name='Máximo'
    )
)

fig.add_trace(
    go.Scatter3d(
        x=[x_values[min_point[1]]],
        y=[y_values[min_point[0]]],
        z=[z_values[min_point]],
        mode='markers',
        marker=dict(color='yellow', size=5),
        name='Mínimo'
    )
)

fig.update_layout(
    title='Gráfico de f(x, y) = sin(xy) + cos(x+y)',
    scene=dict(
        xaxis_title='x',
        yaxis_title='y',
        zaxis_title='f(x, y)'
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
